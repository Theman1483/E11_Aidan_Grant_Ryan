# %%
import csv
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "data/simpletest.csv"

# %%
df = pd.read_csv(file_path)

# %%
plt.plot(df["PM2.5 env"])

# %%
plt.hist(df["PM2.5 env"],bins = 2)
plt.ylabel('Frequency')
plt.xlabel('PM2.5 env')
plt.title('PM2.5 env Distribution')
# Out:
# Text(0.5, 1.0, 'PM2.5 env Distribution')
